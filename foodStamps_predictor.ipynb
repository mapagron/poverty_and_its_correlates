# %%
import pandas as pd

# %%
health_df = pd.read_csv("health_data.csv", encoding="ISO-8859-1")
df = pd.read_csv("city_poverty.csv", encoding="ISO-8859-1")

# %%
df_small = df[["GEO.display-label","HC04_EST_VC01", "HC01_EST_VC26"]]
us_state_abbrev = {
    'Alabama': 'AL','Alaska': 'AK','Arizona': 'AZ','Arkansas': 'AR','California': 'CA','Colorado': 'CO',
    'Connecticut': 'CT','Delaware': 'DE','Florida': 'FL','Georgia': 'GA','Hawaii': 'HI','Idaho': 'ID','Illinois': 'IL','Indiana': 'IN','Iowa': 'IA','Kansas': 'KS',
    'Kentucky': 'KY','Louisiana': 'LA','Maine': 'ME','Maryland': 'MD','Massachusetts': 'MA','Michigan': 'MI',
    'Minnesota': 'MN','Mississippi': 'MS','Missouri': 'MO','Montana': 'MT','Nebraska': 'NE','Nevada': 'NV',
    'New Hampshire': 'NH','New Jersey': 'NJ','New Mexico': 'NM','New York': 'NY','North Carolina': 'NC',
    'North Dakota': 'ND','Ohio': 'OH','Oklahoma': 'OK','Oregon': 'OR','Pennsylvania': 'PA','Rhode Island': 'RI',
    'South Carolina': 'SC','South Dakota': 'SD','Tennessee': 'TN','Texas': 'TX','Utah': 'UT','Vermont': 'VT',
    'Virginia': 'VA','Washington': 'WA','West Virginia': 'WV','Wisconsin': 'WI','Wyoming': 'WY','Puerto Rico': 'PR',
    'District of Columbia': 'DC'
}
df_small = df_small.drop([0])
df_small.head()
df_small["city"] = ""
df_small["state"] = ""
df_small.head()
stop_words = ["city", "municipality", "CDP", "town", "unified government (balance)" ,"consolidated government (balance)",
        "village", "metro government (balance)", "metropolitan government (balance)", "zona urbana", "(balance)"]
for df_index, df_row in df_small.iterrows():
        item = df_row["GEO.display-label"]
        state = item.split(",")[-1].strip()
        state_abbr = us_state_abbrev[state]
        string = df_row["GEO.display-label"]
        city_state = item.split(",")[0]
        city = ' '.join([word for word in city_state.split() if word not in stop_words])
        df_row["city"] = city
        df_row["state"] = us_state_abbrev[state]
df_small["city"].replace("Athens-Clarke County unified government", "Athens", inplace=True)
df_small["city"].replace("Augusta-Richmond County consolidated government", "Augusta", inplace=True)
df_small["city"].replace("Macon-Bibb County", "Macon", inplace=True)
df_small["city"].replace("Macon-Bibb County", "Macon", inplace=True)
df_small["city"].replace("Urban Honolulu", "Honolulu", inplace=True)
df_small["city"].replace("Urban Honolulu", "Honolulu", inplace=True)
df_small["city"].replace("Lexington-Fayette urban county", "Lexington", inplace=True)
df_small["city"].replace("Louisville/Jefferson County metro government", "Louisville", inplace=True)
df_small["city"].replace("Nashville-Davidson metropolitan government", "Nashville", inplace=True)
df_small["city"].replace("Louisville/Jefferson County metro government", "Louisville", inplace=True)
df_small["city"].replace("Louisville/Jefferson County metro government", "Louisville", inplace=True)
new_df = pd.merge(df_small, health_df,  how='inner', left_on=['city','state'], right_on = ['PlaceName','StateAbbr'])
new_df
# Out:
#                    GEO.display-label HC04_EST_VC01 HC01_EST_VC26  \
# 0           Birmingham city, Alabama          25.4         68383
# 1               Hoover city, Alabama           5.6         30290
# 2           Huntsville city, Alabama          12.8         67417
# 3               Mobile city, Alabama          19.5         62948
# 4           Montgomery city, Alabama          20.9         65565
# 5           Tuscaloosa city, Alabama           8.9         28958
# 6     Anchorage municipality, Alaska           8.8         99234
# 7             Avondale city, Arizona          16.7         22491
# 8             Chandler city, Arizona           4.9         84362
# 9              Gilbert town, Arizona             5         70822
# 10            Glendale city, Arizona          17.3         71637
# 11                Mesa city, Arizona            11        148223
# 12              Peoria city, Arizona           6.9         53928
# 13             Phoenix city, Arizona            16        457839
# 14          Scottsdale city, Arizona           3.6        103490
# 15            Surprise city, Arizona           6.6         43150
# 16               Tempe city, Arizona           7.4         58880
# 17              Tucson city, Arizona          18.4        159747
# 18                Yuma city, Arizona          17.8         28047
# 19       Fayetteville city, Arkansas           5.6         24603
# 20         Fort Smith city, Arkansas          18.2         28413
# 21          Jonesboro city, Arkansas          15.6         24182
# 22        Little Rock city, Arkansas           9.7         69367
# 23         Springdale city, Arkansas          13.4         24968
# 24          Alameda city, California           4.7         28001
# 25         Alhambra city, California           4.5         24042
# 26          Anaheim city, California            13         86349
# 27          Antioch city, California          15.1         30021
# 28     Apple Valley town, California          24.4         20885
# 29      Bakersfield city, California          17.8         96760
# ..                               ...           ...           ...
# 467           Hampton city, Virginia            13         46405
# 468         Lynchburg city, Virginia          15.1         23182
# 469      Newport News city, Virginia          11.9         59633
# 470           Norfolk city, Virginia          15.6         72654
# 471        Portsmouth city, Virginia          17.8         31067
# 472          Richmond city, Virginia          17.7         70927
# 473           Roanoke city, Virginia          16.3         31560
# 474           Suffolk city, Virginia          11.8         30000
# 475    Virginia Beach city, Virginia             6        155607
# 476          Auburn city, Washington          17.6         26809
# 477        Bellevue city, Washington           5.5         52728
# 478      Bellingham city, Washington          15.5         26410
# 479         Everett city, Washington          20.4         36114
# 480     Federal Way city, Washington            16         31004
# 481       Kennewick city, Washington          15.8         24554
# 482            Kent city, Washington          19.2         39219
# 483          Renton city, Washington          15.7         34285
# 484         Seattle city, Washington           8.4        286289
# 485         Spokane city, Washington          21.4         73446
# 486  Spokane Valley city, Washington          15.6         34587
# 487          Tacoma city, Washington          19.2         68932
# 488       Vancouver city, Washington          18.6         61817
# 489          Yakima city, Washington          23.5         27377
# 490         Appleton city, Wisconsin          10.3         25533
# 491        Green Bay city, Wisconsin          14.8         36065
# 492          Kenosha city, Wisconsin          23.4         31804
# 493          Madison city, Wisconsin           8.4         93908
# 494        Milwaukee city, Wisconsin          29.6        169903
# 495           Racine city, Wisconsin          29.3         23495
# 496         Waukesha city, Wisconsin          13.2         25567
#
#                city state  Unnamed: 0 StateAbbr       PlaceName  PlaceFIPS  \
# 0        Birmingham    AL           0        AL      Birmingham     107000
# 1            Hoover    AL           1        AL          Hoover     135896
# 2        Huntsville    AL           2        AL      Huntsville     137000
# 3            Mobile    AL           3        AL          Mobile     150000
# 4        Montgomery    AL           4        AL      Montgomery     151000
# 5        Tuscaloosa    AL           5        AL      Tuscaloosa     177256
# 6         Anchorage    AK           6        AK       Anchorage     203000
# 7          Avondale    AZ           7        AZ        Avondale     404720
# 8          Chandler    AZ           8        AZ        Chandler     412000
# 9           Gilbert    AZ           9        AZ         Gilbert     427400
# 10         Glendale    AZ          10        AZ        Glendale     427820
# 11             Mesa    AZ          11        AZ            Mesa     446000
# 12           Peoria    AZ          12        AZ          Peoria     454050
# 13          Phoenix    AZ          13        AZ         Phoenix     455000
# 14       Scottsdale    AZ          14        AZ      Scottsdale     465000
# 15         Surprise    AZ          15        AZ        Surprise     471510
# 16            Tempe    AZ          16        AZ           Tempe     473000
# 17           Tucson    AZ          17        AZ          Tucson     477000
# 18             Yuma    AZ          18        AZ            Yuma     485540
# 19     Fayetteville    AR          19        AR    Fayetteville     523290
# 20       Fort Smith    AR          20        AR      Fort Smith     524550
# 21        Jonesboro    AR          21        AR       Jonesboro     535710
# 22      Little Rock    AR          22        AR     Little Rock     541000
# 23       Springdale    AR          23        AR      Springdale     566080
# 24          Alameda    CA          24        CA         Alameda     600562
# 25         Alhambra    CA          25        CA        Alhambra     600884
# 26          Anaheim    CA          26        CA         Anaheim     602000
# 27          Antioch    CA          27        CA         Antioch     602252
# 28     Apple Valley    CA          28        CA    Apple Valley     602364
# 29      Bakersfield    CA          29        CA     Bakersfield     603526
# ..              ...   ...         ...       ...             ...        ...
# 467         Hampton    VA         468        VA         Hampton    5135000
# 468       Lynchburg    VA         469        VA       Lynchburg    5147672
# 469    Newport News    VA         470        VA    Newport News    5156000
# 470         Norfolk    VA         471        VA         Norfolk    5157000
# 471      Portsmouth    VA         472        VA      Portsmouth    5164000
# 472        Richmond    VA         473        VA        Richmond    5167000
# 473         Roanoke    VA         474        VA         Roanoke    5168000
# 474         Suffolk    VA         475        VA         Suffolk    5176432
# 475  Virginia Beach    VA         476        VA  Virginia Beach    5182000
# 476          Auburn    WA         477        WA          Auburn    5303180
# 477        Bellevue    WA         478        WA        Bellevue    5305210
# 478      Bellingham    WA         479        WA      Bellingham    5305280
# 479         Everett    WA         480        WA         Everett    5322640
# 480     Federal Way    WA         481        WA     Federal Way    5323515
# 481       Kennewick    WA         482        WA       Kennewick    5335275
# 482            Kent    WA         483        WA            Kent    5335415
# 483          Renton    WA         484        WA          Renton    5357745
# 484         Seattle    WA         485        WA         Seattle    5363000
# 485         Spokane    WA         486        WA         Spokane    5367000
# 486  Spokane Valley    WA         487        WA  Spokane Valley    5367167
# 487          Tacoma    WA         488        WA          Tacoma    5370000
# 488       Vancouver    WA         489        WA       Vancouver    5374060
# 489          Yakima    WA         490        WA          Yakima    5380010
# 490        Appleton    WI         492        WI        Appleton    5502375
# 491       Green Bay    WI         493        WI       Green Bay    5531000
# 492         Kenosha    WI         494        WI         Kenosha    5539225
# 493         Madison    WI         495        WI         Madison    5548000
# 494       Milwaukee    WI         496        WI       Milwaukee    5553000
# 495          Racine    WI         497        WI          Racine    5566000
# 496        Waukesha    WI         498        WI        Waukesha    5584250
#
#      Population2010              ...                SLEEP_Adj95CI  \
# 0            212237              ...                 (46.6, 47.0)
# 1             81619              ...                 (34.2, 35.0)
# 2            180105              ...                 (39.4, 40.0)
# 3            195111              ...                 (42.0, 42.4)
# 4            205764              ...                 (41.0, 41.5)
# 5             90468              ...                 (41.0, 41.8)
# 6            291826              ...                 (33.2, 33.6)
# 7             76238              ...                 (35.9, 36.5)
# 8            236123              ...                 (32.7, 33.1)
# 9            208453              ...                 (31.8, 32.3)
# 10           226721              ...                 (35.6, 35.9)
# 11           439041              ...                 (34.5, 34.8)
# 12           154065              ...                 (33.3, 33.7)
# 13          1445632              ...                 (35.6, 35.7)
# 14           217385              ...                 (30.5, 31.0)
# 15           117517              ...                 (33.4, 34.0)
# 16           161719              ...                 (33.8, 34.3)
# 17           520116              ...                 (34.7, 34.9)
# 18            93064              ...                 (35.7, 36.2)
# 19            73580              ...                 (33.1, 34.0)
# 20            86209              ...                 (37.7, 38.3)
# 21            67263              ...                 (35.3, 36.3)
# 22           193524              ...                 (36.3, 36.8)
# 23            69797              ...                 (35.8, 36.6)
# 24            73812              ...                 (31.9, 32.6)
# 25            83089              ...                 (38.1, 38.8)
# 26           336265              ...                 (33.6, 34.0)
# 27           102372              ...                 (37.6, 38.1)
# 28            69135              ...                 (36.3, 37.0)
# 29           347483              ...                 (34.6, 34.9)
# ..              ...              ...                          ...
# 467          137436              ...                 (44.2, 44.7)
# 468           75568              ...                 (37.7, 38.5)
# 469          180719              ...                 (41.5, 41.9)
# 470          242803              ...                 (39.6, 40.1)
# 471           95535              ...                 (39.7, 40.3)
# 472          204214              ...                 (39.7, 40.2)
# 473           97032              ...                 (38.7, 39.4)
# 474           84585              ...                 (38.9, 39.6)
# 475          437994              ...                 (35.9, 36.3)
# 476           70180              ...                 (33.1, 33.8)
# 477          122363              ...                 (28.8, 29.3)
# 478           80885              ...                 (27.0, 27.8)
# 479          103019              ...                 (35.4, 36.0)
# 480           89306              ...                 (33.4, 33.9)
# 481           73917              ...                 (32.7, 33.5)
# 482           92411              ...                 (33.9, 34.4)
# 483           90927              ...                 (32.6, 33.1)
# 484          608660              ...                 (29.7, 30.0)
# 485          208916              ...                 (32.7, 33.1)
# 486           89755              ...                 (32.1, 32.8)
# 487          198397              ...                 (37.5, 37.9)
# 488          161791              ...                 (34.1, 34.6)
# 489           91067              ...                 (34.0, 34.6)
# 490           72623              ...                 (28.3, 29.0)
# 491          104057              ...                 (31.7, 32.3)
# 492           99218              ...                 (33.1, 33.8)
# 493          233209              ...                 (30.0, 30.5)
# 494          594833              ...                 (40.7, 40.9)
# 495           78860              ...                 (36.0, 36.6)
# 496           70718              ...                 (29.3, 30.1)
#
#     STROKE_CrudePrev  STROKE_Crude95CI STROKE_AdjPrev  STROKE_Adj95CI  \
# 0                5.0      ( 5.0,  5.1)            5.0    ( 5.0,  5.1)
# 1                2.3      ( 2.2,  2.3)            2.2    ( 2.1,  2.3)
# 2                3.3      ( 3.3,  3.4)            3.2    ( 3.1,  3.2)
# 3                4.3      ( 4.3,  4.4)            4.1    ( 4.0,  4.1)
# 4                4.0      ( 3.9,  4.1)            4.1    ( 4.0,  4.1)
# 5                3.1      ( 3.0,  3.2)            4.1    ( 4.0,  4.2)
# 6                2.2      ( 2.2,  2.2)            2.6    ( 2.6,  2.6)
# 7                2.3      ( 2.2,  2.3)            3.1    ( 3.0,  3.2)
# 8                2.0      ( 2.0,  2.1)            2.4    ( 2.3,  2.4)
# 9                1.8      ( 1.7,  1.8)            2.2    ( 2.1,  2.2)
# 10               2.8      ( 2.8,  2.8)            3.1    ( 3.0,  3.1)
# 11               3.0      ( 3.0,  3.1)            2.9    ( 2.8,  2.9)
# 12               2.8      ( 2.7,  2.9)            2.5    ( 2.5,  2.6)
# 13               2.7      ( 2.7,  2.8)            3.1    ( 3.1,  3.1)
# 14               2.7      ( 2.7,  2.8)            2.1    ( 2.1,  2.2)
# 15               3.0      ( 2.9,  3.1)            2.5    ( 2.4,  2.6)
# 16               2.0      ( 1.9,  2.0)            2.7    ( 2.6,  2.7)
# 17               3.0      ( 2.9,  3.0)            3.1    ( 3.1,  3.1)
# 18               3.1      ( 3.0,  3.1)            3.1    ( 3.0,  3.2)
# 19               2.0      ( 1.9,  2.1)            2.8    ( 2.7,  2.9)
# 20               3.7      ( 3.6,  3.8)            3.6    ( 3.5,  3.7)
# 21               3.0      ( 2.9,  3.1)            3.2    ( 3.1,  3.3)
# 22               3.3      ( 3.3,  3.4)            3.4    ( 3.3,  3.4)
# 23               3.1      ( 3.0,  3.2)            3.5    ( 3.4,  3.6)
# 24               2.4      ( 2.3,  2.5)            2.2    ( 2.1,  2.3)
# 25               2.5      ( 2.4,  2.5)            2.3    ( 2.3,  2.4)
# 26               2.4      ( 2.4,  2.5)            2.7    ( 2.7,  2.8)
# 27               2.7      ( 2.6,  2.7)            2.9    ( 2.8,  3.0)
# 28               3.5      ( 3.4,  3.6)            3.0    ( 2.9,  3.1)
# 29               2.7      ( 2.7,  2.8)            3.1    ( 3.1,  3.1)
# ..               ...               ...            ...             ...
# 467              3.5      ( 3.4,  3.5)            3.5    ( 3.4,  3.6)
# 468              3.3      ( 3.2,  3.4)            3.5    ( 3.4,  3.5)
# 469              3.1      ( 3.0,  3.1)            3.3    ( 3.3,  3.4)
# 470              3.0      ( 2.9,  3.0)            3.6    ( 3.6,  3.7)
# 471              4.0      ( 3.9,  4.1)            3.9    ( 3.8,  3.9)
# 472              3.6      ( 3.5,  3.6)            4.0    ( 4.0,  4.1)
# 473              3.8      ( 3.7,  3.9)            3.5    ( 3.4,  3.6)
# 474              3.3      ( 3.2,  3.4)            3.2    ( 3.2,  3.3)
# 475              2.3      ( 2.3,  2.4)            2.5    ( 2.4,  2.5)
# 476              2.9      ( 2.8,  3.0)            3.0    ( 3.0,  3.1)
# 477              2.1      ( 2.0,  2.1)            2.0    ( 1.9,  2.0)
# 478              2.5      ( 2.4,  2.6)            2.7    ( 2.6,  2.8)
# 479              2.7      ( 2.6,  2.7)            2.9    ( 2.8,  3.0)
# 480              2.8      ( 2.7,  2.8)            2.9    ( 2.8,  3.0)
# 481              2.9      ( 2.8,  3.0)            3.0    ( 2.9,  3.1)
# 482              2.7      ( 2.7,  2.8)            3.0    ( 3.0,  3.1)
# 483              2.4      ( 2.4,  2.5)            2.6    ( 2.6,  2.7)
# 484              2.1      ( 2.1,  2.1)            2.4    ( 2.3,  2.4)
# 485              3.0      ( 2.9,  3.0)            3.0    ( 2.9,  3.0)
# 486              3.0      ( 2.9,  3.1)            2.7    ( 2.7,  2.8)
# 487              2.9      ( 2.9,  3.0)            3.0    ( 3.0,  3.1)
# 488              2.9      ( 2.8,  2.9)            2.8    ( 2.8,  2.9)
# 489              3.5      ( 3.4,  3.6)            3.3    ( 3.3,  3.4)
# 490              2.4      ( 2.4,  2.5)            2.4    ( 2.4,  2.5)
# 491              2.8      ( 2.7,  2.9)            2.9    ( 2.8,  3.0)
# 492              2.8      ( 2.7,  2.9)            2.9    ( 2.8,  3.0)
# 493              1.9      ( 1.9,  1.9)            2.3    ( 2.3,  2.4)
# 494              3.4      ( 3.4,  3.4)            3.9    ( 3.9,  3.9)
# 495              3.2      ( 3.2,  3.3)            3.3    ( 3.2,  3.4)
# 496              2.2      ( 2.2,  2.3)            2.4    ( 2.3,  2.4)
#
#     TEETHLOST_CrudePrev  TEETHLOST_Crude95CI TEETHLOST_AdjPrev  \
# 0                  26.1         (25.1, 27.2)              25.9
# 1                   9.6         ( 8.6, 10.8)               9.5
# 2                  14.9         (14.1, 15.7)              14.7
# 3                  24.3         (23.4, 25.3)              24.1
# 4                  21.2         (20.3, 22.2)              21.2
# 5                  20.9         (19.5, 22.4)              20.6
# 6                  12.6         (12.1, 13.2)              13.0
# 7                  15.3         (14.2, 16.5)              16.1
# 8                   9.7         ( 9.1, 10.5)               9.9
# 9                   7.9         ( 7.4,  8.5)               8.3
# 10                 14.6         (13.9, 15.5)              14.8
# 11                 13.4         (12.7, 14.0)              13.2
# 12                 11.0         (10.2, 11.9)              10.9
# 13                 14.4         (14.1, 14.7)              14.6
# 14                  7.8         ( 7.3,  8.4)               7.7
# 15                 10.1         ( 9.0, 11.3)              10.6
# 16                 10.6         ( 9.8, 11.7)              10.7
# 17                 13.7         (13.2, 14.1)              13.5
# 18                 16.2         (15.1, 17.5)              16.0
# 19                 15.8         (13.9, 18.0)              15.6
# 20                 21.5         (19.9, 23.1)              21.5
# 21                 18.9         (16.9, 21.0)              18.7
# 22                 15.9         (15.0, 16.8)              15.8
# 23                 24.4         (22.1, 26.7)              24.4
# 24                  7.6         ( 6.9,  8.4)               7.5
# 25                  9.1         ( 8.3,  9.9)               8.8
# 26                 11.4         (10.9, 11.8)              11.4
# 27                 12.1         (11.2, 13.0)              12.2
# 28                 12.7         (11.5, 14.1)              12.7
# 29                 13.6         (13.0, 14.2)              13.7
# ..                  ...                  ...               ...
# 467                16.1         (15.2, 17.0)              16.1
# 468                16.9         (15.4, 18.5)              16.6
# 469                15.3         (14.4, 16.1)              15.2
# 470                17.9         (17.2, 18.7)              17.7
# 471                19.5         (18.1, 21.0)              19.3
# 472                19.3         (18.3, 20.2)              19.2
# 473                17.3         (16.0, 18.7)              17.0
# 474                15.9         (14.9, 17.0)              16.1
# 475                11.1         (10.6, 11.6)              11.2
# 476                14.4         (13.1, 15.9)              14.5
# 477                 6.8         ( 6.1,  7.5)               6.7
# 478                12.4         (11.0, 14.0)              12.1
# 479                13.0         (12.1, 14.2)              12.9
# 480                12.4         (11.3, 13.5)              12.4
# 481                15.5         (14.1, 17.2)              15.4
# 482                13.4         (12.3, 14.6)              13.5
# 483                10.9         (10.0, 12.0)              10.9
# 484                 8.5         ( 8.1,  8.9)               8.4
# 485                14.3         (13.4, 15.2)              14.0
# 486                13.3         (12.3, 14.4)              13.1
# 487                14.1         (13.4, 15.0)              14.0
# 488                12.9         (12.1, 13.8)              12.8
# 489                18.7         (16.8, 20.6)              18.3
# 490                12.7         (11.5, 14.0)              12.5
# 491                15.5         (14.2, 16.9)              15.2
# 492                17.4         (16.0, 19.0)              17.1
# 493                 9.9         ( 9.2, 10.7)               9.8
# 494                19.8         (19.3, 20.3)              19.7
# 495                18.3         (16.8, 19.8)              18.2
# 496                11.9         (10.7, 13.4)              11.8
#
#      TEETHLOST_Adj95CI                    Geolocation
# 0         (25.0, 26.9)  33.52756637730 -86.7988174678
# 1         ( 8.5, 10.9)  33.37676027290 -86.8051937568
# 2         (13.8, 15.5)  34.69896926710 -86.6387042882
# 3         (23.1, 25.0)  30.67762486480 -88.1184482714
# 4         (20.1, 22.2)  32.34726453330 -86.2677059552
# 5         (19.2, 21.9)  33.23360839510 -87.5268004073
# 6         (12.4, 13.7)  61.14986873100 -149.111113424
# 7         (14.9, 17.2)  33.38583674050 -112.323626619
# 8         ( 9.2, 10.7)  33.28318981000 -111.852210033
# 9         ( 7.7,  9.0)  33.31014939200 -111.746237467
# 10        (14.1, 15.7)  33.57961230890 -112.225306421
# 11        (12.5, 13.8)  33.40228373590 -111.718721181
# 12        (10.1, 11.8)  33.78472064220 -112.298680584
# 13        (14.3, 14.9)  33.57241386950 -112.088995222
# 14        ( 7.3,  8.3)  33.68724936510 -111.865085877
# 15        ( 9.3, 11.9)  33.68038351770 -112.452218439
# 16        ( 9.9, 11.7)  33.38826403070 -111.931802302
# 17        (13.1, 14.0)  32.15672444830 -110.877085494
# 18        (14.8, 17.3)  32.59860271170 -114.548368370
# 19        (13.7, 17.7)  36.07121173120 -94.1659600436
# 20        (20.2, 23.3)  35.34916926360 -94.3696317306
# 21        (16.7, 20.6)  35.82081215380 -90.6794991686
# 22        (15.0, 16.7)  34.72539578940 -92.3583751863
# 23        (22.0, 26.8)  36.18699325980 -94.1536274531
# 24        ( 6.7,  8.3)  37.76508490310 -122.266489842
# 25        ( 8.2,  9.6)  34.08397343830 -118.135514119
# 26        (10.9, 11.8)  33.83890769960 -117.857613481
# 27        (11.4, 13.0)  37.97770429220 -121.796606971
# 28        (11.5, 13.9)  34.53159849480 -117.211012664
# 29        (13.1, 14.3)  35.35133028550 -119.029786003
# ..                 ...                            ...
# 467       (15.1, 17.0)  37.05330090250 -76.3665945624
# 468       (15.4, 17.9)  37.40041630160 -79.1911081000
# 469       (14.4, 15.9)  37.10511413090 -76.5182644502
# 470       (17.0, 18.6)  36.89328630060 -76.2567157761
# 471       (17.8, 20.8)  36.84514502280 -76.3552763467
# 472       (18.2, 20.1)  37.52939330830 -77.4755681680
# 473       (15.8, 18.3)  37.27821818550 -79.9581615989
# 474       (15.0, 17.1)  36.69303679810 -76.6414278469
# 475       (10.7, 11.7)  36.75345933390 -76.0589579522
# 476       (13.1, 16.0)  47.30385443250 -122.210810557
# 477       ( 6.0,  7.3)  47.59624376060 -122.153569982
# 478       (10.8, 13.8)  48.75353703150 -122.468092906
# 479       (11.8, 14.1)  47.94979661890 -122.160703911
# 480       (11.4, 13.3)  47.30908463160 -122.335755583
# 481       (13.9, 17.1)  46.19843842800 -119.173245847
# 482       (12.3, 14.8)  47.38496362720 -122.217890194
# 483       (10.1, 11.9)  47.47605467520 -122.191153327
# 484       ( 8.1,  8.8)  47.62215433800 -122.323532482
# 485       (13.2, 14.8)  47.67362432590 -117.415973291
# 486       (12.2, 14.1)  47.66255657400 -117.234571922
# 487       (13.3, 14.8)  47.24254114450 -122.454473910
# 488       (11.9, 13.7)  45.63571723650 -122.598539476
# 489       (16.6, 20.0)  46.59257920920 -120.547807614
# 490       (11.3, 13.8)  44.27769874570 -88.3897664444
# 491       (13.9, 16.5)  44.51498478160 -87.9896195955
# 492       (15.8, 18.9)  42.58557027100 -87.8735745085
# 493       ( 9.1, 10.5)  43.08098656940 -89.3915106344
# 494       (19.2, 20.2)  43.06412589250 -87.9672412429
# 495       (16.9, 19.6)  42.72745994940 -87.8134530240
# 496       (10.5, 13.1)  43.00933322150 -88.2457679157
#
# [497 rows x 123 columns]

# %%
new_df = new_df.rename(columns={'HC04_EST_VC01': '%onFoodStamps', 'HC01_EST_VC26': '#atOr_abovePoverty'})

# %%
new_df.head()
# Out:
#           GEO.display-label %onFoodStamps #atOr_abovePoverty        city  \
# 0  Birmingham city, Alabama          25.4              68383  Birmingham
# 1      Hoover city, Alabama           5.6              30290      Hoover
# 2  Huntsville city, Alabama          12.8              67417  Huntsville
# 3      Mobile city, Alabama          19.5              62948      Mobile
# 4  Montgomery city, Alabama          20.9              65565  Montgomery
#
#   state  Unnamed: 0 StateAbbr   PlaceName  PlaceFIPS  Population2010  \
# 0    AL           0        AL  Birmingham     107000          212237
# 1    AL           1        AL      Hoover     135896           81619
# 2    AL           2        AL  Huntsville     137000          180105
# 3    AL           3        AL      Mobile     150000          195111
# 4    AL           4        AL  Montgomery     151000          205764
#
#                ...                SLEEP_Adj95CI STROKE_CrudePrev  \
# 0              ...                 (46.6, 47.0)              5.0
# 1              ...                 (34.2, 35.0)              2.3
# 2              ...                 (39.4, 40.0)              3.3
# 3              ...                 (42.0, 42.4)              4.3
# 4              ...                 (41.0, 41.5)              4.0
#
#    STROKE_Crude95CI STROKE_AdjPrev  STROKE_Adj95CI TEETHLOST_CrudePrev  \
# 0      ( 5.0,  5.1)            5.0    ( 5.0,  5.1)                26.1
# 1      ( 2.2,  2.3)            2.2    ( 2.1,  2.3)                 9.6
# 2      ( 3.3,  3.4)            3.2    ( 3.1,  3.2)                14.9
# 3      ( 4.3,  4.4)            4.1    ( 4.0,  4.1)                24.3
# 4      ( 3.9,  4.1)            4.1    ( 4.0,  4.1)                21.2
#
#    TEETHLOST_Crude95CI TEETHLOST_AdjPrev  TEETHLOST_Adj95CI  \
# 0         (25.1, 27.2)              25.9       (25.0, 26.9)
# 1         ( 8.6, 10.8)               9.5       ( 8.5, 10.9)
# 2         (14.1, 15.7)              14.7       (13.8, 15.5)
# 3         (23.4, 25.3)              24.1       (23.1, 25.0)
# 4         (20.3, 22.2)              21.2       (20.1, 22.2)
#
#                      Geolocation
# 0  33.52756637730 -86.7988174678
# 1  33.37676027290 -86.8051937568
# 2  34.69896926710 -86.6387042882
# 3  30.67762486480 -88.1184482714
# 4  32.34726453330 -86.2677059552
#
# [5 rows x 123 columns]

# %%
new_df.to_csv("health_poverty.csv")

# %%
list(new_df.columns.values)
# Out:
# ['GEO.display-label',
#  '%onFoodStamps',
#  '#atOr_abovePoverty',
#  'city',
#  'state',
#  'Unnamed: 0',
#  'StateAbbr',
#  'PlaceName',
#  'PlaceFIPS',
#  'Population2010',
#  'ACCESS2_CrudePrev',
#  'ACCESS2_Crude95CI',
#  'ACCESS2_AdjPrev',
#  'ACCESS2_Adj95CI',
#  'ARTHRITIS_CrudePrev',
#  'ARTHRITIS_Crude95CI',
#  'ARTHRITIS_AdjPrev',
#  'ARTHRITIS_Adj95CI',
#  'BINGE_CrudePrev',
#  'BINGE_Crude95CI',
#  'BINGE_AdjPrev',
#  'BINGE_Adj95CI',
#  'BPHIGH_CrudePrev',
#  'BPHIGH_Crude95CI',
#  'BPHIGH_AdjPrev',
#  'BPHIGH_Adj95CI',
#  'BPMED_CrudePrev',
#  'BPMED_Crude95CI',
#  'BPMED_AdjPrev',
#  'BPMED_Adj95CI',
#  'CANCER_CrudePrev',
#  'CANCER_Crude95CI',
#  'CANCER_AdjPrev',
#  'CANCER_Adj95CI',
#  'CASTHMA_CrudePrev',
#  'CASTHMA_Crude95CI',
#  'CASTHMA_AdjPrev',
#  'CASTHMA_Adj95CI',
#  'CHD_CrudePrev',
#  'CHD_Crude95CI',
#  'CHD_AdjPrev',
#  'CHD_Adj95CI',
#  'CHECKUP_CrudePrev',
#  'CHECKUP_Crude95CI',
#  'CHECKUP_AdjPrev',
#  'CHECKUP_Adj95CI',
#  'CHOLSCREEN_CrudePrev',
#  'CHOLSCREEN_Crude95CI',
#  'CHOLSCREEN_AdjPrev',
#  'CHOLSCREEN_Adj95CI',
#  'COLON_SCREEN_CrudePrev',
#  'COLON_SCREEN_Crude95CI',
#  'COLON_SCREEN_AdjPrev',
#  'COLON_SCREEN_Adj95CI',
#  'COPD_CrudePrev',
#  'COPD_Crude95CI',
#  'COPD_AdjPrev',
#  'COPD_Adj95CI',
#  'COREM_CrudePrev',
#  'COREM_Crude95CI',
#  'COREM_AdjPrev',
#  'COREM_Adj95CI',
#  'COREW_CrudePrev',
#  'COREW_Crude95CI',
#  'COREW_AdjPrev',
#  'COREW_Adj95CI',
#  'CSMOKING_CrudePrev',
#  'CSMOKING_Crude95CI',
#  'CSMOKING_AdjPrev',
#  'CSMOKING_Adj95CI',
#  'DENTAL_CrudePrev',
#  'DENTAL_Crude95CI',
#  'DENTAL_AdjPrev',
#  'DENTAL_Adj95CI',
#  'DIABETES_CrudePrev',
#  'DIABETES_Crude95CI',
#  'DIABETES_AdjPrev',
#  'DIABETES_Adj95CI',
#  'HIGHCHOL_CrudePrev',
#  'HIGHCHOL_Crude95CI',
#  'HIGHCHOL_AdjPrev',
#  'HIGHCHOL_Adj95CI',
#  'KIDNEY_CrudePrev',
#  'KIDNEY_Crude95CI',
#  'KIDNEY_AdjPrev',
#  'KIDNEY_Adj95CI',
#  'LPA_CrudePrev',
#  'LPA_Crude95CI',
#  'LPA_AdjPrev',
#  'LPA_Adj95CI',
#  'MAMMOUSE_CrudePrev',
#  'MAMMOUSE_Crude95CI',
#  'MAMMOUSE_AdjPrev',
#  'MAMMOUSE_Adj95CI',
#  'MHLTH_CrudePrev',
#  'MHLTH_Crude95CI',
#  'MHLTH_AdjPrev',
#  'MHLTH_Adj95CI',
#  'OBESITY_CrudePrev',
#  'OBESITY_Crude95CI',
#  'OBESITY_AdjPrev',
#  'OBESITY_Adj95CI',
#  'PAPTEST_CrudePrev',
#  'PAPTEST_Crude95CI',
#  'PAPTEST_AdjPrev',
#  'PAPTEST_Adj95CI',
#  'PHLTH_CrudePrev',
#  'PHLTH_Crude95CI',
#  'PHLTH_AdjPrev',
#  'PHLTH_Adj95CI',
#  'SLEEP_CrudePrev',
#  'SLEEP_Crude95CI',
#  'SLEEP_AdjPrev',
#  'SLEEP_Adj95CI',
#  'STROKE_CrudePrev',
#  'STROKE_Crude95CI',
#  'STROKE_AdjPrev',
#  'STROKE_Adj95CI',
#  'TEETHLOST_CrudePrev',
#  'TEETHLOST_Crude95CI',
#  'TEETHLOST_AdjPrev',
#  'TEETHLOST_Adj95CI',
#  'Geolocation']

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Assign X (data) and y (target)

X = new_df[['BINGE_AdjPrev', 'BPHIGH_AdjPrev', 'PAPTEST_AdjPrev', 'ACCESS2_AdjPrev', 'ARTHRITIS_AdjPrev', 'STROKE_AdjPrev', 'TEETHLOST_AdjPrev', 'COLON_SCREEN_AdjPrev', 'CANCER_AdjPrev', 'CHECKUP_AdjPrev', 'CHOLSCREEN_AdjPrev', 'CSMOKING_AdjPrev', 'DENTAL_AdjPrev', 'DIABETES_AdjPrev', 'HIGHCHOL_AdjPrev', 'KIDNEY_AdjPrev', 'LPA_AdjPrev', 'MAMMOUSE_AdjPrev', 'MHLTH_AdjPrev', 'OBESITY_AdjPrev', 'PHLTH_AdjPrev', 'SLEEP_AdjPrev']]
y = new_df["%onFoodStamps"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (497, 22) (497, 1)

# %%
# Split the data into training and testing
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScater model and fit it to the training data
X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)
# Out:
# /Users/michaeldurst/anaconda/envs/PythonData/lib/python3.6/site-packages/sklearn/utils/validation.py:429: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, _DataConversionWarning)

# %%
# Transform the training and testing data using the X_scaler and y_scaler models

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)
# Out:
# /Users/michaeldurst/anaconda/envs/PythonData/lib/python3.6/site-packages/sklearn/utils/validation.py:429: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, _DataConversionWarning)

# %%
# Create a LinearRegression model and fit it to the scaled training data
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_scaled, y_train_scaled)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Make predictions using the X_test_scaled data
# Plot y_test_scaled vs y_test_scaled
# Scatter plot y_test_scaled vs predictions

predictions = model.predict(X_test_scaled)
plt.plot(y_test_scaled, y_test_scaled, c='red')
plt.scatter(y_test_scaled, predictions, c='blue')
plt.show()

# %%
# Used X_test_scaled, y_test_scaled, and model.predict(X_test_scaled) to calculate MSE and R2

from sklearn.metrics import mean_squared_error

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = model.score(X_test_scaled, y_test_scaled)

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.19928913283513416, R2: 0.7621845931417413

# %%
# LASSO model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import Lasso

lasso = Lasso(alpha=.01).fit(X_train_scaled, y_train_scaled)

predictions = lasso.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = lasso.score(X_test_scaled, y_test_scaled)

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.19350087301916785, R2: 0.7690918305989592

# %%
# Ridge model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import Ridge

ridge = Ridge(alpha=.01).fit(X_train_scaled, y_train_scaled)

predictions = ridge.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = ridge.score(X_test_scaled, y_test_scaled)


print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.19925709986750878, R2: 0.7622228186742643

# %%
# ElasticNet model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import ElasticNet


elasticnet = ElasticNet(alpha=.01).fit(X_train_scaled, y_train_scaled)

predictions = elasticnet.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = elasticnet.score(X_test_scaled, y_test_scaled)


print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.19361492528030005, R2: 0.768955729927044
